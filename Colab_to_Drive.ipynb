# %% [markdown]
# <a href="https://colab.research.google.com/github/krishmithlesh/Face_Recognition/blob/master/Colab_to_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#install PyDrive
# !pip install -U -q PyDrive

# %%
#Import all required libraries 
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#You can find out file id by right clicking on file and by going to Get sharable link
download = drive.CreateFile({'id': '1a6OIfIJvo01YPwnVgEigPy1H-uLgA0y1'})

# %%
download.GetContentFile('Face_Detection_Folder.zip')

# %%
# !unzip att_faces.zip
# Out:
# Archive:  att_faces.zip
#    creating: Face_Detection_Folder/
#    creating: Face_Detection_Folder/att_faces/
#   inflating: Face_Detection_Folder/att_faces/README
#    creating: Face_Detection_Folder/att_faces/s1/
#   inflating: Face_Detection_Folder/att_faces/s1/6.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/7.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/8.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/9.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/10.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/1.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/2.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/3.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/4.pgm
#   inflating: Face_Detection_Folder/att_faces/s1/5.pgm
#    creating: Face_Detection_Folder/att_faces/s2/
#   inflating: Face_Detection_Folder/att_faces/s2/6.pgm
#   inflating: Face_Detection_Folder/att_faces/s2/7.pgm
#   inflating: Face_Detection_Folder/att_faces/s2/8.pgm
# ...

# %%
ls
# Out:
# adc.json       Face_Detection_Folder/     sample_data/
# att_faces.zip  Face_Detection_Folder.zip

# %%
ls
# Out:
# adc.json  Face_Detection_Folder/  Face_Detection_Folder.zip  sample_data/

# %%
cd Face_Detection_Folder/
# Out:
# /content/Face_Detection_Folder

# %%
pip install face_recognition
# Out:
# ...
#      |████████████████████████████████| 100.2MB 1.4MB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=bf011ffd98ad894918d055a70be0fa1fce8e75f8c3c5072cebd44bc5e73f8a63
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
# !python3 encode_faces.py --dataset att_faces --encodings encodings.pickle --detection-method cnn
# Out:
# [INFO] quantifying faces...
# [INFO] processing image 1/15
# [INFO] processing image 2/15
# [INFO] processing image 3/15
# [INFO] processing image 4/15
# [INFO] processing image 5/15
# [INFO] processing image 6/15
# [INFO] processing image 7/15
# [INFO] processing image 8/15
# [INFO] processing image 9/15
# [INFO] processing image 10/15
# [INFO] processing image 11/15
# [INFO] processing image 12/15
# [INFO] processing image 13/15
# [INFO] processing image 14/15
# [INFO] processing image 15/15
# [INFO] serializing encodings...
